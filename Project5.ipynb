# %% [markdown]
# # Project 4 - SafeZone: Mapping Covid19 and Natural Disasters
# ---

# %% [markdown]
# ## Table of Contents
#
# 1. [Problem Statement](#Problem-Statement)
# 2. [Executive Summary](#Executive-Summary)
# 3. [API Scraping](#API-Scraping)
# 4. [Function to Get Posts](#Function-to-Get-Posts)
# 5. [Function to Get Comments](#Function-to-Get-Comments)

# %% [markdown]
# ## Problem Statement
# ---
#
# What is Your Action Plan during a Federal Emergency?
#
# There seems to be an unprecedented amount of natural disasters in 2020. In addition to the more common seasonal hurricanes, tornadoes and floods, there have been wildfires, earthquakes, civil unrest and even ‘murder hornets’. All of these risks have been magnified by Covid.
#
# Regardless of whether there are more of these instances this year or it just seems that way because of Covid, it is important to have an action plan readily available during a disaster or emergency, especially if you are unfamiliar with a given location or a potential destination.
#
# Our team has developed an application that will alert you when an emergency in your location has occurred and then provide you a plan to “prepare for, respond to and mitigate emergencies, including natural and man-made disasters.”

# %% [markdown]
# ---
# ## Imports

# %%
# Standards
import pandas as pd
import numpy as np
import math

# API
import requests
import json

# Automating
import time
import datetime
import warnings
import sys
import urllib.request

from time import sleep
from datetime import datetime

# %% [markdown]
# ## API Data Pulls

# %% [markdown]
# ### FEMA API

# %%
# FemaWebDisasterSummaries

# %%
# Base URL for this endpoint. Add filters, column selection, and sort order to this.
baseUrl = "https://www.fema.gov/api/open/v1/FemaWebDisasterSummaries?"


top = 1000      # number of records to get per call
skip = 0        # number of records to skip


# Return 1 record with your criteria to get total record count. Specifying only 1
#   column here to reduce amount of data returned. Need inlinecount to get record count. 
webUrl = urllib.request.urlopen(baseUrl + "$inlinecount=allpages&$select=id&$top=1")
result = webUrl.read()
jsonData = json.loads(result.decode())


# calculate the number of calls we will need to get all of our data (using the maximum of 1000)
recCount = jsonData['metadata']['count']
loopNum = math.ceil(recCount / top)


# send some logging info to the console so we know what is happening
print("START " + str(datetime.now()) + ", " + str(recCount) + " records, " + str(top) + " returned per call, " + str(loopNum) + " iterations needed.")


# Initialize our file. Only doing this because of the type of file wanted. See the loop below.
#   The root json entity is usually the name of the dataset, but you can use any name.
outFile = open("FemaWebDisasterSummaries.json", "a")
outFile.write('{"FemaWebDisasterSummaries":[')


# Loop and call the API endpoint changing the record start each iteration. The metadata is being
#   suppressed as we no longer need it.
i = 0
while (i < loopNum):
    # By default data is returned as a JSON object, the data set name being the root element. Unless
    #   you extract records as you process, you will end up with 1 distinct JSON object for EVERY 
    #   call/iteration. An alternative is to return the data as JSONA (an array of json objects) with 
    #   no root element - just a bracket at the start and end. This is easier to manipulate.
    webUrl = urllib.request.urlopen(baseUrl + "&$metadata=off&$format=jsona&$skip=" + str(skip) + "&$top=" + str(top))
    result = webUrl.read()
    
    # The data is already returned in a JSON format. There is no need to decode and load as a JSON object.
    #   If you want to begin working with and manipulating the JSON, import the json library and load with
    #   something like: jsonData = json.loads(result.decode())


    # Append results to file, trimming off first and last JSONA brackets, adding comma except for last call,
    #   AND root element terminating array bracket and brace to end unless on last call. The goal here is to 
    #   create a valid JSON file that contains ALL the records. This can be done differently.
    if (i == (loopNum - 1)):
        # on the last so terminate the single JSON object
        outFile.write(str(result[1:-1],'utf-8') + "]}")
    else:
        outFile.write(str(result[1:-1],'utf-8') + ",")


    # increment the loop counter and skip value
    i+=1
    skip = i * top


    print("Iteration " + str(i) + " done")


outFile.close()


# lets re-open the file and see if we got the number of records we expected
inFile = open("FemaWebDisasterSummaries.json", "r")
my_data = json.load(inFile)
print("END " + str(datetime.now()) + ", " + str(len(my_data['FemaWebDisasterSummaries'])) + " records in file")
inFile.close()
# Out:
# START 2020-10-30 01:17:20.942040, 3254 records, 1000 returned per call, 4 iterations needed.
# Iteration 1 done
# Iteration 2 done
# Iteration 3 done
# Iteration 4 done
# END 2020-10-30 01:17:22.242327, 3254 records in file

# %%
# DisasterDeclarationsSummaries

# %%
# Base URL for this endpoint. Add filters, column selection, and sort order to this.
baseUrl = "https://www.fema.gov/api/open/v2/DisasterDeclarationsSummaries?"


top = 1000      # number of records to get per call
skip = 0        # number of records to skip


# Return 1 record with your criteria to get total record count. Specifying only 1
#   column here to reduce amount of data returned. Need inlinecount to get record count. 
webUrl = urllib.request.urlopen(baseUrl + "$inlinecount=allpages&$select=id&$top=1")
result = webUrl.read()
jsonData = json.loads(result.decode())


# calculate the number of calls we will need to get all of our data (using the maximum of 1000)
recCount = jsonData['metadata']['count']
loopNum = math.ceil(recCount / top)


# send some logging info to the console so we know what is happening
print("START " + str(datetime.now()) + ", " + str(recCount) + " records, " + str(top) + " returned per call, " + str(loopNum) + " iterations needed.")


# Initialize our file. Only doing this because of the type of file wanted. See the loop below.
#   The root json entity is usually the name of the dataset, but you can use any name.
outFile = open("DisasterDeclarationsSummaries.json", "a")
outFile.write('{"DisasterDeclarationsSummaries":[')


# Loop and call the API endpoint changing the record start each iteration. The metadata is being
#   suppressed as we no longer need it.
i = 0
while (i < loopNum):
    # By default data is returned as a JSON object, the data set name being the root element. Unless
    #   you extract records as you process, you will end up with 1 distinct JSON object for EVERY 
    #   call/iteration. An alternative is to return the data as JSONA (an array of json objects) with 
    #   no root element - just a bracket at the start and end. This is easier to manipulate.
    webUrl = urllib.request.urlopen(baseUrl + "&$metadata=off&$format=jsona&$skip=" + str(skip) + "&$top=" + str(top))
    result = webUrl.read()
    
    # The data is already returned in a JSON format. There is no need to decode and load as a JSON object.
    #   If you want to begin working with and manipulating the JSON, import the json library and load with
    #   something like: jsonData = json.loads(result.decode())


    # Append results to file, trimming off first and last JSONA brackets, adding comma except for last call,
    #   AND root element terminating array bracket and brace to end unless on last call. The goal here is to 
    #   create a valid JSON file that contains ALL the records. This can be done differently.
    if (i == (loopNum - 1)):
        # on the last so terminate the single JSON object
        outFile.write(str(result[1:-1],'utf-8') + "]}")
    else:
        outFile.write(str(result[1:-1],'utf-8') + ",")


    # increment the loop counter and skip value
    i+=1
    skip = i * top


    print("Iteration " + str(i) + " done")


outFile.close()


# lets re-open the file and see if we got the number of records we expected
inFile = open("DisasterDeclarationsSummaries.json", "r")
my_data = json.load(inFile)
print("END " + str(datetime.now()) + ", " + str(len(my_data['DisasterDeclarationsSummaries'])) + " records in file")
inFile.close()
# Out:
# START 2020-10-29 15:01:32.510373, 60356 records, 1000 returned per call, 61 iterations needed.
# Iteration 1 done
# Iteration 2 done
# Iteration 3 done
# Iteration 4 done
# Iteration 5 done
# Iteration 6 done
# Iteration 7 done
# Iteration 8 done
# Iteration 9 done
# Iteration 10 done
# Iteration 11 done
# Iteration 12 done
# Iteration 13 done
# Iteration 14 done
# Iteration 15 done
# Iteration 16 done
# Iteration 17 done
# Iteration 18 done
# Iteration 19 done
# Iteration 20 done
# Iteration 21 done
# Iteration 22 done
# Iteration 23 done
# Iteration 24 done
# Iteration 25 done
# Iteration 26 done
# Iteration 27 done
# Iteration 28 done
# Iteration 29 done
# Iteration 30 done
# Iteration 31 done
# Iteration 32 done
# Iteration 33 done
# Iteration 34 done
# Iteration 35 done
# Iteration 36 done
# Iteration 37 done
# Iteration 38 done
# Iteration 39 done
# Iteration 40 done
# Iteration 41 done
# Iteration 42 done
# Iteration 43 done
# Iteration 44 done
# Iteration 45 done
# Iteration 46 done
# Iteration 47 done
# Iteration 48 done
# Iteration 49 done
# Iteration 50 done
# Iteration 51 done
# Iteration 52 done
# Iteration 53 done
# Iteration 54 done
# Iteration 55 done
# Iteration 56 done
# Iteration 57 done
# Iteration 58 done
# Iteration 59 done
# Iteration 60 done
# Iteration 61 done
# END 2020-10-29 15:02:13.113612, 60356 records in file

# %% [markdown]
# ### Reading in the JSON files into DataFrames

# %%
# This is the whole FEMA dataset

# %%
# Loading JSON file line by line using list comprehension
disaster_summaries = [json.loads(line) for line in open('DisasterDeclarationsSummaries.json', 'r')]
disaster_summaries
# Out:
# [{'DisasterDeclarationsSummaries': [{'femaDeclarationString': 'DR-1-GA',
#     'disasterNumber': 1,
#     'state': 'GA',
#     'declarationType': 'DR',
#     'declarationDate': '1953-05-02T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-05-02T04:00:00.000Z',
#     'incidentEndDate': '1953-05-02T04:00:00.000Z',
#     'disasterCloseoutDate': '1954-06-01T04:00:00.000Z',
#     'fipsStateCode': '13',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53013',
#     'hash': '2f28952448e0a666d367ca3f854c81ec',
#     'lastRefresh': '2020-10-05T14:21:20.694Z',
#     'id': '5f7b2be031a8c6681cfb4342'},
#    {'femaDeclarationString': 'DR-2-TX',
#     'disasterNumber': 2,
#     'state': 'TX',
#     'declarationType': 'DR',
#     'declarationDate': '1953-05-15T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO & HEAVY RAINFALL',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-05-15T04:00:00.000Z',
#     'incidentEndDate': '1953-05-15T04:00:00.000Z',
#     'disasterCloseoutDate': '1958-01-01T05:00:00.000Z',
#     'fipsStateCode': '48',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53003',
#     'hash': 'c5a1a4a1030d6730d9c562cdbe7c830f',
#     'lastRefresh': '2020-10-05T14:21:20.696Z',
#     'id': '5f7b2be031a8c6681cfb4345'},
#    {'femaDeclarationString': 'DR-5-MT',
#     'disasterNumber': 5,
#     'state': 'MT',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-06T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-06T04:00:00.000Z',
#     'incidentEndDate': '1953-06-06T04:00:00.000Z',
#     'disasterCloseoutDate': '1955-12-01T05:00:00.000Z',
#     'fipsStateCode': '30',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53006',
#     'hash': '59c5483387ca13c6a3c1bc692f4860e1',
#     'lastRefresh': '2020-10-05T14:21:20.698Z',
#     'id': '5f7b2be031a8c6681cfb4348'},
#    {'femaDeclarationString': 'DR-7-MA',
#     'disasterNumber': 7,
#     'state': 'MA',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-11T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-11T04:00:00.000Z',
#     'incidentEndDate': '1953-06-11T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-06-01T04:00:00.000Z',
#     'fipsStateCode': '25',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53009',
#     'hash': '6bab17e16984fc75f61a8445df3e95d9',
#     'lastRefresh': '2020-10-05T14:21:20.699Z',
#     'id': '5f7b2be031a8c6681cfb434b'},
#    {'femaDeclarationString': 'DR-8-IA',
#     'disasterNumber': 8,
#     'state': 'IA',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-11T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-11T04:00:00.000Z',
#     'incidentEndDate': '1953-06-11T04:00:00.000Z',
#     'disasterCloseoutDate': '1955-11-01T05:00:00.000Z',
#     'fipsStateCode': '19',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53008',
#     'hash': 'e258e9dd25fac73939f59c8ffb5308f5',
#     'lastRefresh': '2020-10-05T14:21:20.700Z',
#     'id': '5f7b2be031a8c6681cfb434e'},
#    {'femaDeclarationString': 'DR-9-TX',
#     'disasterNumber': 9,
#     'state': 'TX',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-19T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-19T04:00:00.000Z',
#     'incidentEndDate': '1953-06-19T04:00:00.000Z',
#     'disasterCloseoutDate': '1958-01-01T05:00:00.000Z',
#     'fipsStateCode': '48',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53010',
#     'hash': '4485da27a9218458eb2d13a6c33a4c62',
#     'lastRefresh': '2020-10-05T14:21:20.700Z',
#     'id': '5f7b2be031a8c6681cfb4351'},
#    {'femaDeclarationString': 'DR-3-LA',
#     'disasterNumber': 3,
#     'state': 'LA',
#     'declarationType': 'DR',
#     'declarationDate': '1953-05-29T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-05-29T04:00:00.000Z',
#     'incidentEndDate': '1953-05-29T04:00:00.000Z',
#     'disasterCloseoutDate': '1960-02-01T05:00:00.000Z',
#     'fipsStateCode': '22',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53005',
#     'hash': '745948932fd77a7c6dcd4de7059ff080',
#     'lastRefresh': '2020-10-05T14:21:20.697Z',
#     'id': '5f7b2be031a8c6681cfb4354'},
#    {'femaDeclarationString': 'DR-4-MI',
#     'disasterNumber': 4,
#     'state': 'MI',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-02T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-02T04:00:00.000Z',
#     'incidentEndDate': '1953-06-02T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-02-01T05:00:00.000Z',
#     'fipsStateCode': '26',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53004',
#     'hash': '8c9dee13124e36a9dfe2eb74e33fafad',
#     'lastRefresh': '2020-10-05T14:21:20.698Z',
#     'id': '5f7b2be031a8c6681cfb4357'},
#    {'femaDeclarationString': 'DR-6-MI',
#     'disasterNumber': 6,
#     'state': 'MI',
#     'declarationType': 'DR',
#     'declarationDate': '1953-06-09T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-06-09T04:00:00.000Z',
#     'incidentEndDate': '1953-06-09T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-03-30T05:00:00.000Z',
#     'fipsStateCode': '26',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53007',
#     'hash': 'd3ae03a5caa78ae1c8b6052e5e29a97d',
#     'lastRefresh': '2020-10-05T14:21:20.699Z',
#     'id': '5f7b2be031a8c6681cfb435a'},
#    {'femaDeclarationString': 'DR-11-NH',
#     'disasterNumber': 11,
#     'state': 'NH',
#     'declarationType': 'DR',
#     'declarationDate': '1953-07-02T04:00:00.000Z',
#     'fyDeclared': 1953,
#     'incidentType': 'Fire',
#     'declarationTitle': 'FOREST FIRE',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-07-02T04:00:00.000Z',
#     'incidentEndDate': '1953-07-02T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-02-01T05:00:00.000Z',
#     'fipsStateCode': '33',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53011',
#     'hash': '86a70820dbb80e585cc01e2ce502005c',
#     'lastRefresh': '2020-10-05T14:21:20.701Z',
#     'id': '5f7b2be031a8c6681cfb435d'},
#    {'femaDeclarationString': 'DR-12-FL',
#     'disasterNumber': 12,
#     'state': 'FL',
#     'declarationType': 'DR',
#     'declarationDate': '1953-10-22T05:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-10-22T05:00:00.000Z',
#     'incidentEndDate': '1953-10-22T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-05-01T04:00:00.000Z',
#     'fipsStateCode': '12',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53015',
#     'hash': '93a695d6b2cbc85dfcdb7658badee008',
#     'lastRefresh': '2020-10-05T14:21:20.701Z',
#     'id': '5f7b2be031a8c6681cfb4360'},
#    {'femaDeclarationString': 'DR-13-AK',
#     'disasterNumber': 13,
#     'state': 'AK',
#     'declarationType': 'DR',
#     'declarationDate': '1953-10-30T05:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Other',
#     'declarationTitle': 'SEVERE HARDSHIP',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-10-30T05:00:00.000Z',
#     'incidentEndDate': '1953-10-30T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-09-01T04:00:00.000Z',
#     'fipsStateCode': '02',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53012',
#     'hash': '626ddcfb06e4c7645541b9794b17d9ac',
#     'lastRefresh': '2020-10-05T14:21:20.702Z',
#     'id': '5f7b2be031a8c6681cfb4363'},
#    {'femaDeclarationString': 'DR-14-MS',
#     'disasterNumber': 14,
#     'state': 'MS',
#     'declarationType': 'DR',
#     'declarationDate': '1953-12-06T05:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1953-12-06T05:00:00.000Z',
#     'incidentEndDate': '1953-12-06T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-06-01T04:00:00.000Z',
#     'fipsStateCode': '28',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '53014',
#     'hash': '667bf59e25f3b0ee78c53d5ca2938885',
#     'lastRefresh': '2020-10-05T14:21:20.702Z',
#     'id': '5f7b2be031a8c6681cfb4366'},
#    {'femaDeclarationString': 'DR-15-CA',
#     'disasterNumber': 15,
#     'state': 'CA',
#     'declarationType': 'DR',
#     'declarationDate': '1954-02-05T05:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD & EROSION',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-02-05T05:00:00.000Z',
#     'incidentEndDate': '1954-02-05T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-09-01T04:00:00.000Z',
#     'fipsStateCode': '06',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54016',
#     'hash': '328d7badea059a9bba05702e62a61c88',
#     'lastRefresh': '2020-10-05T14:21:20.702Z',
#     'id': '5f7b2be031a8c6681cfb4369'},
#    {'femaDeclarationString': 'DR-18-TX',
#     'disasterNumber': 18,
#     'state': 'TX',
#     'declarationType': 'DR',
#     'declarationDate': '1954-07-01T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-07-01T04:00:00.000Z',
#     'incidentEndDate': '1954-07-01T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-07-01T04:00:00.000Z',
#     'fipsStateCode': '48',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54004',
#     'hash': 'c515d85a0d0f4c7fc56c154a9749ef0d',
#     'lastRefresh': '2020-10-05T14:21:20.703Z',
#     'id': '5f7b2be031a8c6681cfb436c'},
#    {'femaDeclarationString': 'DR-19-NV',
#     'disasterNumber': 19,
#     'state': 'NV',
#     'declarationType': 'DR',
#     'declarationDate': '1954-07-14T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Earthquake',
#     'declarationTitle': 'EARTHQUAKE',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-07-14T04:00:00.000Z',
#     'incidentEndDate': '1954-07-14T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-08-01T04:00:00.000Z',
#     'fipsStateCode': '32',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54010',
#     'hash': 'b704664570b0b558ff05e3d09d6a748c',
#     'lastRefresh': '2020-10-05T14:21:20.703Z',
#     'id': '5f7b2be031a8c6681cfb436f'},
#    {'femaDeclarationString': 'DR-20-SD',
#     'disasterNumber': 20,
#     'state': 'SD',
#     'declarationType': 'DR',
#     'declarationDate': '1954-07-31T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-07-31T04:00:00.000Z',
#     'incidentEndDate': '1954-07-31T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-02-01T05:00:00.000Z',
#     'fipsStateCode': '46',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54005',
#     'hash': '00ba3aa61296f0a515c0ace3cdef1646',
#     'lastRefresh': '2020-10-05T14:21:20.703Z',
#     'id': '5f7b2be031a8c6681cfb4372'},
#    {'femaDeclarationString': 'DR-30-IN',
#     'disasterNumber': 30,
#     'state': 'IN',
#     'declarationType': 'DR',
#     'declarationDate': '1954-10-26T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-10-26T05:00:00.000Z',
#     'incidentEndDate': '1954-10-26T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-03-01T05:00:00.000Z',
#     'fipsStateCode': '18',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54018',
#     'hash': '93b25091c447f1c4f3fbc0f28dd28d24',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb4375'},
#    {'femaDeclarationString': 'DR-21-WV',
#     'disasterNumber': 21,
#     'state': 'WV',
#     'declarationType': 'DR',
#     'declarationDate': '1954-08-04T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-08-04T04:00:00.000Z',
#     'incidentEndDate': '1954-08-04T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-05-01T04:00:00.000Z',
#     'fipsStateCode': '54',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54007',
#     'hash': '49bbf1cf9bf7da3b56d96db23a763f2c',
#     'lastRefresh': '2020-10-05T14:21:20.703Z',
#     'id': '5f7b2be031a8c6681cfb4378'},
#    {'femaDeclarationString': 'DR-22-MA',
#     'disasterNumber': 22,
#     'state': 'MA',
#     'declarationType': 'DR',
#     'declarationDate': '1954-09-02T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-09-02T04:00:00.000Z',
#     'incidentEndDate': '1954-09-02T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-12-01T05:00:00.000Z',
#     'fipsStateCode': '25',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54008',
#     'hash': 'e1ea5a501caa3e07accacb01514fc4a2',
#     'lastRefresh': '2020-10-05T14:21:20.704Z',
#     'id': '5f7b2be031a8c6681cfb437b'},
#    {'femaDeclarationString': 'DR-26-NY',
#     'disasterNumber': 26,
#     'state': 'NY',
#     'declarationType': 'DR',
#     'declarationDate': '1954-10-07T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-10-07T05:00:00.000Z',
#     'incidentEndDate': '1954-10-07T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-12-01T05:00:00.000Z',
#     'fipsStateCode': '36',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54012',
#     'hash': 'f4f008fe06c567ca122d9ad0fbd673ee',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb437e'},
#    {'femaDeclarationString': 'DR-29-SC',
#     'disasterNumber': 29,
#     'state': 'SC',
#     'declarationType': 'DR',
#     'declarationDate': '1954-10-17T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-10-17T05:00:00.000Z',
#     'incidentEndDate': '1954-10-17T05:00:00.000Z',
#     'disasterCloseoutDate': '1959-01-01T05:00:00.000Z',
#     'fipsStateCode': '45',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54015',
#     'hash': 'd56a0d57ed742d0d8d775e00d417cb6d',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb4381'},
#    {'femaDeclarationString': 'DR-27-NM',
#     'disasterNumber': 27,
#     'state': 'NM',
#     'declarationType': 'DR',
#     'declarationDate': '1954-10-13T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-10-13T05:00:00.000Z',
#     'incidentEndDate': '1954-10-13T05:00:00.000Z',
#     'disasterCloseoutDate': '1959-12-01T05:00:00.000Z',
#     'fipsStateCode': '35',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54017',
#     'hash': 'c90b329e2bf7b2a9e65b6335b87c15f5',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb4384'},
#    {'femaDeclarationString': 'DR-31-AK',
#     'disasterNumber': 31,
#     'state': 'AK',
#     'declarationType': 'DR',
#     'declarationDate': '1954-11-10T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Other',
#     'declarationTitle': 'SEVERE HARDSHIP',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-11-10T05:00:00.000Z',
#     'incidentEndDate': '1954-11-10T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-09-01T04:00:00.000Z',
#     'fipsStateCode': '02',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54019',
#     'hash': 'ec0178a831761b9a28a7c32d50e1b6a6',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb4387'},
#    {'femaDeclarationString': 'DR-32-HI',
#     'disasterNumber': 32,
#     'state': 'HI',
#     'declarationType': 'DR',
#     'declarationDate': '1955-04-01T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Volcano',
#     'declarationTitle': 'VOLCANO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-04-01T05:00:00.000Z',
#     'incidentEndDate': '1955-04-01T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-06-01T04:00:00.000Z',
#     'fipsStateCode': '15',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55003',
#     'hash': '2eea0755c760e955a081c16f1f19cb00',
#     'lastRefresh': '2020-10-05T14:21:20.706Z',
#     'id': '5f7b2be031a8c6681cfb438a'},
#    {'femaDeclarationString': 'DR-28-NC',
#     'disasterNumber': 28,
#     'state': 'NC',
#     'declarationType': 'DR',
#     'declarationDate': '1954-10-17T05:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-10-17T05:00:00.000Z',
#     'incidentEndDate': '1954-10-17T05:00:00.000Z',
#     'disasterCloseoutDate': '1959-01-01T05:00:00.000Z',
#     'fipsStateCode': '37',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54014',
#     'hash': '75059184664f0ad41f3209046cbf2c34',
#     'lastRefresh': '2020-10-05T14:21:20.705Z',
#     'id': '5f7b2be031a8c6681cfb438d'},
#    {'femaDeclarationString': 'DR-16-GA',
#     'disasterNumber': 16,
#     'state': 'GA',
#     'declarationType': 'DR',
#     'declarationDate': '1954-03-17T05:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-03-17T05:00:00.000Z',
#     'incidentEndDate': '1954-03-17T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-11-01T05:00:00.000Z',
#     'fipsStateCode': '13',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54003',
#     'hash': 'bc5b0df384133a376759b7029b1287c4',
#     'lastRefresh': '2020-10-05T14:21:20.702Z',
#     'id': '5f7b2be031a8c6681cfb4390'},
#    {'femaDeclarationString': 'DR-35-OK',
#     'disasterNumber': 35,
#     'state': 'OK',
#     'declarationType': 'DR',
#     'declarationDate': '1955-06-01T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD & TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-06-01T04:00:00.000Z',
#     'incidentEndDate': '1955-06-01T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-12-01T05:00:00.000Z',
#     'fipsStateCode': '40',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55006',
#     'hash': '86a293fe340776e68bea14f6c1730b3c',
#     'lastRefresh': '2020-10-05T14:21:20.706Z',
#     'id': '5f7b2be031a8c6681cfb4393'},
#    {'femaDeclarationString': 'DR-36-NV',
#     'disasterNumber': 36,
#     'state': 'NV',
#     'declarationType': 'DR',
#     'declarationDate': '1955-06-21T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-06-21T04:00:00.000Z',
#     'incidentEndDate': '1955-06-21T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-10-01T04:00:00.000Z',
#     'fipsStateCode': '32',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55007',
#     'hash': '6a6e7c493c07fae3c7059c2b2a816a06',
#     'lastRefresh': '2020-10-05T14:21:20.706Z',
#     'id': '5f7b2be031a8c6681cfb4396'},
#    {'femaDeclarationString': 'DR-37-NC',
#     'disasterNumber': 37,
#     'state': 'NC',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-13T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-13T04:00:00.000Z',
#     'incidentEndDate': '1955-08-13T04:00:00.000Z',
#     'disasterCloseoutDate': '1961-02-10T05:00:00.000Z',
#     'fipsStateCode': '37',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55008',
#     'hash': '73037c2265ccc067f14ad7c3e0f78d0a',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb4399'},
#    {'femaDeclarationString': 'DR-33-CO',
#     'disasterNumber': 33,
#     'state': 'CO',
#     'declarationType': 'DR',
#     'declarationDate': '1955-05-25T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-05-25T04:00:00.000Z',
#     'incidentEndDate': '1955-05-25T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-04-01T05:00:00.000Z',
#     'fipsStateCode': '08',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55004',
#     'hash': '5faa8ad7680e31794d1f11e674a0f064',
#     'lastRefresh': '2020-10-05T14:21:20.706Z',
#     'id': '5f7b2be031a8c6681cfb439c'},
#    {'femaDeclarationString': 'DR-17-IA',
#     'disasterNumber': 17,
#     'state': 'IA',
#     'declarationType': 'DR',
#     'declarationDate': '1954-06-23T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-06-23T04:00:00.000Z',
#     'incidentEndDate': '1954-06-23T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-02-01T05:00:00.000Z',
#     'fipsStateCode': '19',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54006',
#     'hash': 'd4a50115f9ad619d545798bfe038055e',
#     'lastRefresh': '2020-10-05T14:21:20.703Z',
#     'id': '5f7b2be031a8c6681cfb439f'},
#    {'femaDeclarationString': 'DR-34-KS',
#     'disasterNumber': 34,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1955-05-27T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-05-27T04:00:00.000Z',
#     'incidentEndDate': '1955-05-27T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-04-01T05:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55005',
#     'hash': '13a5330af7ab2750377b797101e33af9',
#     'lastRefresh': '2020-10-05T14:21:20.706Z',
#     'id': '5f7b2be031a8c6681cfb43a2'},
#    {'femaDeclarationString': 'DR-23-RI',
#     'disasterNumber': 23,
#     'state': 'RI',
#     'declarationType': 'DR',
#     'declarationDate': '1954-09-02T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-09-02T04:00:00.000Z',
#     'incidentEndDate': '1954-09-02T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-12-01T05:00:00.000Z',
#     'fipsStateCode': '44',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54009',
#     'hash': '783ee52d151cb0592e16110237094197',
#     'lastRefresh': '2020-10-05T14:21:20.704Z',
#     'id': '5f7b2be031a8c6681cfb43a5'},
#    {'femaDeclarationString': 'DR-24-ME',
#     'disasterNumber': 24,
#     'state': 'ME',
#     'declarationType': 'DR',
#     'declarationDate': '1954-09-13T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-09-13T04:00:00.000Z',
#     'incidentEndDate': '1954-09-13T04:00:00.000Z',
#     'disasterCloseoutDate': '1956-12-01T05:00:00.000Z',
#     'fipsStateCode': '23',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54011',
#     'hash': 'fdf79be9521f2e0f6e6d45e5c2534e87',
#     'lastRefresh': '2020-10-05T14:21:20.704Z',
#     'id': '5f7b2be031a8c6681cfb43a8'},
#    {'femaDeclarationString': 'DR-25-CT',
#     'disasterNumber': 25,
#     'state': 'CT',
#     'declarationType': 'DR',
#     'declarationDate': '1954-09-17T04:00:00.000Z',
#     'fyDeclared': 1954,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1954-09-17T04:00:00.000Z',
#     'incidentEndDate': '1954-09-17T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-01-01T05:00:00.000Z',
#     'fipsStateCode': '09',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '54013',
#     'hash': 'db3cb2ac1ebf7ee3b5d9a1a0915e698f',
#     'lastRefresh': '2020-10-05T14:21:20.704Z',
#     'id': '5f7b2be031a8c6681cfb43ab'},
#    {'femaDeclarationString': 'DR-39-RI',
#     'disasterNumber': 39,
#     'state': 'RI',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE & FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1961-04-01T05:00:00.000Z',
#     'fipsStateCode': '44',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55010',
#     'hash': '551bdadc9da77c117c946637ae829510',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb43af'},
#    {'femaDeclarationString': 'DR-40-PA',
#     'disasterNumber': 40,
#     'state': 'PA',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOODS & RAINS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1962-01-01T05:00:00.000Z',
#     'fipsStateCode': '42',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55011',
#     'hash': 'a7253723a50bdd4f9f8496af806cfe4a',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb43b2'},
#    {'femaDeclarationString': 'DR-41-NJ',
#     'disasterNumber': 41,
#     'state': 'NJ',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE & FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-02-01T05:00:00.000Z',
#     'fipsStateCode': '34',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55012',
#     'hash': 'e396323df3ced6302984268f6049ceb2',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb43b5'},
#    {'femaDeclarationString': 'DR-42-CT',
#     'disasterNumber': 42,
#     'state': 'CT',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE, TORRENTIAL RAIN & FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1962-11-20T05:00:00.000Z',
#     'fipsStateCode': '09',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55013',
#     'hash': '4b727732ecb32d61f720d176508ed2ea',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb43b8'},
#    {'femaDeclarationString': 'DR-43-MA',
#     'disasterNumber': 43,
#     'state': 'MA',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE & FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1962-03-20T05:00:00.000Z',
#     'fipsStateCode': '25',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55014',
#     'hash': 'e51e8284dc258aba930a3975ec72dfb5',
#     'lastRefresh': '2020-10-05T14:21:20.708Z',
#     'id': '5f7b2be031a8c6681cfb43bb'},
#    {'femaDeclarationString': 'DR-44-SC',
#     'disasterNumber': 44,
#     'state': 'SC',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-20T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-20T04:00:00.000Z',
#     'incidentEndDate': '1955-08-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-01-01T05:00:00.000Z',
#     'fipsStateCode': '45',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55016',
#     'hash': 'd5834edb41e38db3b9128280b6ce1410',
#     'lastRefresh': '2020-10-05T14:21:20.708Z',
#     'id': '5f7b2be031a8c6681cfb43be'},
#    {'femaDeclarationString': 'DR-45-NY',
#     'disasterNumber': 45,
#     'state': 'NY',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-22T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE & FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-22T04:00:00.000Z',
#     'incidentEndDate': '1955-08-22T04:00:00.000Z',
#     'disasterCloseoutDate': '1957-02-01T05:00:00.000Z',
#     'fipsStateCode': '36',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55015',
#     'hash': '9235645e723fd863dc7523466de58279',
#     'lastRefresh': '2020-10-05T14:21:20.708Z',
#     'id': '5f7b2be031a8c6681cfb43c0'},
#    {'femaDeclarationString': 'DR-46-AK',
#     'disasterNumber': 46,
#     'state': 'AK',
#     'declarationType': 'DR',
#     'declarationDate': '1955-12-22T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Other',
#     'declarationTitle': 'SEVERE HARDSHIP',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-12-22T05:00:00.000Z',
#     'incidentEndDate': '1955-12-22T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-12-01T05:00:00.000Z',
#     'fipsStateCode': '02',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55017',
#     'hash': '7f8102082327defd0909d9c75a7a51a9',
#     'lastRefresh': '2020-10-05T14:21:20.708Z',
#     'id': '5f7b2be031a8c6681cfb43c3'},
#    {'femaDeclarationString': 'DR-38-NM',
#     'disasterNumber': 38,
#     'state': 'NM',
#     'declarationType': 'DR',
#     'declarationDate': '1955-08-15T04:00:00.000Z',
#     'fyDeclared': 1955,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-08-15T04:00:00.000Z',
#     'incidentEndDate': '1955-08-15T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-06-01T04:00:00.000Z',
#     'fipsStateCode': '35',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55009',
#     'hash': '0db5ee4e7c8324ab38a41511d53868da',
#     'lastRefresh': '2020-10-05T14:21:20.707Z',
#     'id': '5f7b2be031a8c6681cfb43c6'},
#    {'femaDeclarationString': 'DR-48-NV',
#     'disasterNumber': 48,
#     'state': 'NV',
#     'declarationType': 'DR',
#     'declarationDate': '1955-12-24T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-12-24T05:00:00.000Z',
#     'incidentEndDate': '1955-12-24T05:00:00.000Z',
#     'disasterCloseoutDate': '1961-09-01T04:00:00.000Z',
#     'fipsStateCode': '32',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55019',
#     'hash': '95fdd5c611b7805ccd120728fe62e91d',
#     'lastRefresh': '2020-10-05T14:21:20.709Z',
#     'id': '5f7b2be031a8c6681cfb43c9'},
#    {'femaDeclarationString': 'DR-47-CA',
#     'disasterNumber': 47,
#     'state': 'CA',
#     'declarationType': 'DR',
#     'declarationDate': '1955-12-23T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-12-23T05:00:00.000Z',
#     'incidentEndDate': '1955-12-23T05:00:00.000Z',
#     'disasterCloseoutDate': '1968-08-12T04:00:00.000Z',
#     'fipsStateCode': '06',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55018',
#     'hash': 'bb6446d134f8a3c6bb5d8409233a5823',
#     'lastRefresh': '2020-10-05T14:21:20.708Z',
#     'id': '5f7b2be031a8c6681cfb43cc'},
#    {'femaDeclarationString': 'DR-49-OR',
#     'disasterNumber': 49,
#     'state': 'OR',
#     'declarationType': 'DR',
#     'declarationDate': '1955-12-29T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1955-12-29T05:00:00.000Z',
#     'incidentEndDate': '1955-12-29T05:00:00.000Z',
#     'disasterCloseoutDate': '1960-10-01T04:00:00.000Z',
#     'fipsStateCode': '41',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '55020',
#     'hash': '0f2b9f55ed0d63f5bc2e2ac28ea3ad67',
#     'lastRefresh': '2020-10-05T14:21:20.709Z',
#     'id': '5f7b2be031a8c6681cfb43ce'},
#    {'femaDeclarationString': 'DR-50-WA',
#     'disasterNumber': 50,
#     'state': 'WA',
#     'declarationType': 'DR',
#     'declarationDate': '1956-02-25T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-02-25T05:00:00.000Z',
#     'incidentEndDate': '1956-02-25T05:00:00.000Z',
#     'disasterCloseoutDate': '1961-07-01T04:00:00.000Z',
#     'fipsStateCode': '53',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56003',
#     'hash': '6914a03b7f13c8cf856e39e47c2a0dee',
#     'lastRefresh': '2020-10-05T14:21:20.709Z',
#     'id': '5f7b2be031a8c6681cfb43d1'},
#    {'femaDeclarationString': 'DR-51-PA',
#     'disasterNumber': 51,
#     'state': 'PA',
#     'declarationType': 'DR',
#     'declarationDate': '1956-03-15T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-03-15T05:00:00.000Z',
#     'incidentEndDate': '1956-03-15T05:00:00.000Z',
#     'disasterCloseoutDate': '1959-06-01T04:00:00.000Z',
#     'fipsStateCode': '42',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56004',
#     'hash': 'e7e1cf9ea2969d2cb3fbf366ae072f1a',
#     'lastRefresh': '2020-10-05T14:21:20.709Z',
#     'id': '5f7b2be031a8c6681cfb43d4'},
#    {'femaDeclarationString': 'DR-52-NY',
#     'disasterNumber': 52,
#     'state': 'NY',
#     'declarationType': 'DR',
#     'declarationDate': '1956-03-29T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-03-29T05:00:00.000Z',
#     'incidentEndDate': '1956-03-29T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-03-01T05:00:00.000Z',
#     'fipsStateCode': '36',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56005',
#     'hash': 'd18a4f2318b5110f510f5f05842d1f36',
#     'lastRefresh': '2020-10-05T14:21:20.709Z',
#     'id': '5f7b2be031a8c6681cfb43d7'},
#    {'femaDeclarationString': 'DR-55-ID',
#     'disasterNumber': 55,
#     'state': 'ID',
#     'declarationType': 'DR',
#     'declarationDate': '1956-04-21T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOODS',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-04-21T05:00:00.000Z',
#     'incidentEndDate': '1956-04-21T05:00:00.000Z',
#     'disasterCloseoutDate': '1961-04-01T05:00:00.000Z',
#     'fipsStateCode': '16',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56006',
#     'hash': 'e7afc2793814912e87bad0635eede9a1',
#     'lastRefresh': '2020-10-05T14:21:20.757Z',
#     'id': '5f7b2be031a8c6681cfb440a'},
#    {'femaDeclarationString': 'DR-56-NC',
#     'disasterNumber': 56,
#     'state': 'NC',
#     'declarationType': 'DR',
#     'declarationDate': '1956-04-24T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Severe Storm(s)',
#     'declarationTitle': 'SEVERE STORM',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-04-24T05:00:00.000Z',
#     'incidentEndDate': '1956-04-24T05:00:00.000Z',
#     'disasterCloseoutDate': '1957-09-01T04:00:00.000Z',
#     'fipsStateCode': '37',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56009',
#     'hash': 'dc32f7821a3d157b3684980aba52abe3',
#     'lastRefresh': '2020-10-05T14:21:20.759Z',
#     'id': '5f7b2be031a8c6681cfb4410'},
#    {'femaDeclarationString': 'DR-59-CO',
#     'disasterNumber': 59,
#     'state': 'CO',
#     'declarationType': 'DR',
#     'declarationDate': '1956-06-12T04:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-06-12T04:00:00.000Z',
#     'incidentEndDate': '1956-06-12T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-04-01T05:00:00.000Z',
#     'fipsStateCode': '08',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56010',
#     'hash': '07e2e0b60bfd8805efc2a5a41195322e',
#     'lastRefresh': '2020-10-05T14:21:20.763Z',
#     'id': '5f7b2be031a8c6681cfb4412'},
#    {'femaDeclarationString': 'DR-60-OR',
#     'disasterNumber': 60,
#     'state': 'OR',
#     'declarationType': 'DR',
#     'declarationDate': '1956-07-20T04:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Flood',
#     'declarationTitle': 'STORM & FLOOD',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-07-20T04:00:00.000Z',
#     'incidentEndDate': '1956-07-20T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-11-01T05:00:00.000Z',
#     'fipsStateCode': '41',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56012',
#     'hash': '42c99c37abdf48a97d7f283d638241bb',
#     'lastRefresh': '2020-10-05T14:21:20.765Z',
#     'id': '5f7b2be031a8c6681cfb4414'},
#    {'femaDeclarationString': 'DR-61-PA',
#     'disasterNumber': 61,
#     'state': 'PA',
#     'declarationType': 'DR',
#     'declarationDate': '1956-08-09T04:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Severe Storm(s)',
#     'declarationTitle': 'STORM',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-08-09T04:00:00.000Z',
#     'incidentEndDate': '1956-08-09T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-06-01T04:00:00.000Z',
#     'fipsStateCode': '42',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56016',
#     'hash': '0eaf1c4de0460300fc5324a57f2d8b69',
#     'lastRefresh': '2020-10-05T14:21:20.766Z',
#     'id': '5f7b2be031a8c6681cfb4416'},
#    {'femaDeclarationString': 'DR-62-PR',
#     'disasterNumber': 62,
#     'state': 'PR',
#     'declarationType': 'DR',
#     'declarationDate': '1956-08-18T04:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Hurricane',
#     'declarationTitle': 'HURRICANE',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-08-18T04:00:00.000Z',
#     'incidentEndDate': '1956-08-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1959-08-01T04:00:00.000Z',
#     'fipsStateCode': '72',
#     'fipsCountyCode': '000',
#     'placeCode': '0',
#     'designatedArea': 'Statewide',
#     'declarationRequestNumber': '56013',
#     'hash': 'ac845d13fa74c945a8d19ee6acd5b640',
#     'lastRefresh': '2020-10-05T14:21:20.768Z',
#     'id': '5f7b2be031a8c6681cfb4418'},
#    {'femaDeclarationString': 'DR-53-MI',
#     'disasterNumber': 53,
#     'state': 'MI',
#     'declarationType': 'DR',
#     'declarationDate': '1956-04-05T05:00:00.000Z',
#     'fyDeclared': 1956,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADO',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': True,
#     'incidentBeginDate': '1956-04-05T05:00:00.000Z',
#     'incidentEndDate': '1956-04-05T05:00:00.000Z',
#     'disasterCloseoutDate': '1956-04-30T04:00:00.000Z',
#     'fipsStateCode': '26',
#     'fipsCountyCode': '000',
# ...
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '077',
#     'placeCode': '99077',
#     'designatedArea': 'Harper (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '650b1c3f60a393cfe7dca3518af53f24',
#     'lastRefresh': '2020-10-05T14:21:22.250Z',
#     'id': '5f7b2be231a8c6681cfb53d0'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '095',
#     'placeCode': '99095',
#     'designatedArea': 'Kingman (County)',
#     'declarationRequestNumber': '67023',
#     'hash': 'e92db9773347a45813d7c1c67832a9fa',
#     'lastRefresh': '2020-10-05T14:21:22.259Z',
#     'id': '5f7b2be231a8c6681cfb53d5'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '055',
#     'placeCode': '99055',
#     'designatedArea': 'Finney (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '4b19094212288f4d81e04447c50b26eb',
#     'lastRefresh': '2020-10-05T14:21:22.248Z',
#     'id': '5f7b2be231a8c6681cfb53d7'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '059',
#     'placeCode': '99059',
#     'designatedArea': 'Franklin (County)',
#     'declarationRequestNumber': '67023',
#     'hash': 'f23ac5770d0d6e24218ecf9d1254ddbb',
#     'lastRefresh': '2020-10-05T14:21:22.249Z',
#     'id': '5f7b2be231a8c6681cfb53d9'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '087',
#     'placeCode': '99087',
#     'designatedArea': 'Jefferson (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '6dd6fc1e6a699a2304456641f90bf3e4',
#     'lastRefresh': '2020-10-05T14:21:22.258Z',
#     'id': '5f7b2be231a8c6681cfb53db'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '103',
#     'placeCode': '99103',
#     'designatedArea': 'Leavenworth (County)',
#     'declarationRequestNumber': '67023',
#     'hash': 'ab33aa8252ead67d8f8b9e10ad08870f',
#     'lastRefresh': '2020-10-05T14:21:22.262Z',
#     'id': '5f7b2be231a8c6681cfb53dd'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '139',
#     'placeCode': '99139',
#     'designatedArea': 'Osage (County)',
#     'declarationRequestNumber': '67023',
#     'hash': 'd07f2f06a66836f98ecc4f2448c97416',
#     'lastRefresh': '2020-10-05T14:21:22.276Z',
#     'id': '5f7b2be231a8c6681cfb53e2'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '135',
#     'placeCode': '99135',
#     'designatedArea': 'Ness (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '1431f494e7fec90bf5fa4d49e8e2dd57',
#     'lastRefresh': '2020-10-05T14:21:22.275Z',
#     'id': '5f7b2be231a8c6681cfb53e5'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '115',
#     'placeCode': '99115',
#     'designatedArea': 'Marion (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '5a5477817e0e210241078966cea93680',
#     'lastRefresh': '2020-10-05T14:21:22.267Z',
#     'id': '5f7b2be231a8c6681cfb53e9'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '121',
#     'placeCode': '99121',
#     'designatedArea': 'Miami (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '7b4ce4ec6c9f76f1827f5ec046530b5b',
#     'lastRefresh': '2020-10-05T14:21:22.268Z',
#     'id': '5f7b2be231a8c6681cfb53ef'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '123',
#     'placeCode': '99123',
#     'designatedArea': 'Mitchell (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '3e207c1ad813b131d7bf2f91f09d550f',
#     'lastRefresh': '2020-10-05T14:21:22.269Z',
#     'id': '5f7b2be231a8c6681cfb53f1'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '107',
#     'placeCode': '99107',
#     'designatedArea': 'Linn (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '729e57232f776922965cecdfdcadebb8',
#     'lastRefresh': '2020-10-05T14:21:22.264Z',
#     'id': '5f7b2be231a8c6681cfb53f7'},
#    {'femaDeclarationString': 'DR-231-ID',
#     'disasterNumber': 231,
#     'state': 'ID',
#     'declarationType': 'DR',
#     'declarationDate': '1967-08-30T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Fire',
#     'declarationTitle': 'FOREST FIRES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-08-30T04:00:00.000Z',
#     'incidentEndDate': '1967-08-30T04:00:00.000Z',
#     'disasterCloseoutDate': '1970-06-17T04:00:00.000Z',
#     'fipsStateCode': '16',
#     'fipsCountyCode': '009',
#     'placeCode': '99009',
#     'designatedArea': 'Benewah (County)',
#     'declarationRequestNumber': '67025',
#     'hash': 'f50cb1e43bec1197c5ced60fcdade977',
#     'lastRefresh': '2020-10-05T14:21:22.281Z',
#     'id': '5f7b2be231a8c6681cfb5401'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '131',
#     'placeCode': '99131',
#     'designatedArea': 'Nemaha (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '9d175e797b804be24d74bfaddac33f91',
#     'lastRefresh': '2020-10-05T14:21:22.272Z',
#     'id': '5f7b2be231a8c6681cfb5404'},
#    {'femaDeclarationString': 'DR-230-AK',
#     'disasterNumber': 230,
#     'state': 'AK',
#     'declarationType': 'DR',
#     'declarationDate': '1967-08-17T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Flood',
#     'declarationTitle': 'SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-08-17T04:00:00.000Z',
#     'incidentEndDate': '1967-08-17T04:00:00.000Z',
#     'disasterCloseoutDate': '1973-11-30T05:00:00.000Z',
#     'fipsStateCode': '02',
#     'fipsCountyCode': '000',
#     'placeCode': '75165',
#     'designatedArea': 'Tanana (ANV/ANVSA)',
#     'declarationRequestNumber': '67024',
#     'hash': '4aed9b6a8b3a294e70b4caa91ff82592',
#     'lastRefresh': '2020-10-05T14:21:22.280Z',
#     'id': '5f7b2be231a8c6681cfb5405'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '111',
#     'placeCode': '99111',
#     'designatedArea': 'Lyon (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '10f68d393500c6e6f10a1925d2ce0a0a',
#     'lastRefresh': '2020-10-05T14:21:22.265Z',
#     'id': '5f7b2be231a8c6681cfb5408'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '157',
#     'placeCode': '99157',
#     'designatedArea': 'Republic (County)',
#     'declarationRequestNumber': '67023',
#     'hash': '4f521d6e4fb911aa0b9260ad20e8ff33',
#     'lastRefresh': '2020-10-05T14:21:22.278Z',
#     'id': '5f7b2be231a8c6681cfb5409'},
#    {'femaDeclarationString': 'DR-229-KS',
#     'disasterNumber': 229,
#     'state': 'KS',
#     'declarationType': 'DR',
#     'declarationDate': '1967-07-18T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Tornado',
#     'declarationTitle': 'TORNADOES, SEVERE STORMS & FLOODING',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-07-18T04:00:00.000Z',
#     'incidentEndDate': '1967-07-18T04:00:00.000Z',
#     'disasterCloseoutDate': '1969-07-09T04:00:00.000Z',
#     'fipsStateCode': '20',
#     'fipsCountyCode': '201',
#     'placeCode': '99201',
#     'designatedArea': 'Washington (County)',
#     'declarationRequestNumber': '67023',
#     'hash': 'b4fc622ea29d0b6a87a14a4c345747f7',
#     'lastRefresh': '2020-10-05T14:21:22.279Z',
#     'id': '5f7b2be231a8c6681cfb540b'},
#    {'femaDeclarationString': 'DR-231-ID',
#     'disasterNumber': 231,
#     'state': 'ID',
#     'declarationType': 'DR',
#     'declarationDate': '1967-08-30T04:00:00.000Z',
#     'fyDeclared': 1967,
#     'incidentType': 'Fire',
#     'declarationTitle': 'FOREST FIRES',
#     'ihProgramDeclared': False,
#     'iaProgramDeclared': True,
#     'paProgramDeclared': True,
#     'hmProgramDeclared': False,
#     'incidentBeginDate': '1967-08-30T04:00:00.000Z',
#     'incidentEndDate': '1967-08-30T04:00:00.000Z',
#     'disasterCloseoutDate': '1970-06-17T04:00:00.000Z',
#     'fipsStateCode': '16',
#     'fipsCountyCode': '017',
#     'placeCode': '99017',
#     'designatedArea': 'Bonner (County)',
#     'declarationRequestNumber': '67025',
#     'hash': '5c985f5f1669c6c102cf35b2f9f5ad5a',
#     'lastRefresh': '2020-10-05T14:21:22.287Z',
#     'id': '5f7b2be231a8c6681cfb540f'},
#    ...]}]

# %%
# confirm length
len(disaster_summaries[0]['DisasterDeclarationsSummaries'])
# Out:
# 60356

# %%
# extract column names
cols = list(disaster_summaries[0]['DisasterDeclarationsSummaries'][0].keys())
cols
# Out:
# ['femaDeclarationString',
#  'disasterNumber',
#  'state',
#  'declarationType',
#  'declarationDate',
#  'fyDeclared',
#  'incidentType',
#  'declarationTitle',
#  'ihProgramDeclared',
#  'iaProgramDeclared',
#  'paProgramDeclared',
#  'hmProgramDeclared',
#  'incidentBeginDate',
#  'incidentEndDate',
#  'disasterCloseoutDate',
#  'fipsStateCode',
#  'fipsCountyCode',
#  'placeCode',
#  'designatedArea',
#  'declarationRequestNumber',
#  'hash',
#  'lastRefresh',
#  'id']

# %%
# check individual entries
list(disaster_summaries[0]['DisasterDeclarationsSummaries'][0].values())
# Out:
# ['DR-1-GA',
#  1,
#  'GA',
#  'DR',
#  '1953-05-02T04:00:00.000Z',
#  1953,
#  'Tornado',
#  'TORNADO',
#  False,
#  True,
#  True,
#  True,
#  '1953-05-02T04:00:00.000Z',
#  '1953-05-02T04:00:00.000Z',
#  '1954-06-01T04:00:00.000Z',
#  '13',
#  '000',
#  '0',
#  'Statewide',
#  '53013',
#  '2f28952448e0a666d367ca3f854c81ec',
#  '2020-10-05T14:21:20.694Z',
#  '5f7b2be031a8c6681cfb4342']

# %%
# for loop to extract list of dictionaries into dataframe
df = pd.DataFrame(columns = cols)
for i in range(len(disaster_summaries[0]['DisasterDeclarationsSummaries'])):
    entry_df = pd.DataFrame(list(disaster_summaries[0]['DisasterDeclarationsSummaries'][i].values()), cols).T
    df = df.append(entry_df)

# %%
# export full dataframe into csv
df.to_csv('DisasterSummariesFULL.csv')

# %%
# code to read in CSV file we just saved
df = pd.read_csv('DisasterSummariesFULL.csv', index_col = 0)

# %%
df.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0               DR-1-GA               1    GA              DR
# 0               DR-2-TX               2    TX              DR
# 0               DR-5-MT               5    MT              DR
# 0               DR-7-MA               7    MA              DR
# 0               DR-8-IA               8    IA              DR
#
#             declarationDate  fyDeclared incidentType  \
# 0  1953-05-02T04:00:00.000Z        1953      Tornado
# 0  1953-05-15T04:00:00.000Z        1953      Tornado
# 0  1953-06-06T04:00:00.000Z        1953        Flood
# 0  1953-06-11T04:00:00.000Z        1953      Tornado
# 0  1953-06-11T04:00:00.000Z        1953        Flood
#
#            declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 0                   TORNADO              False               True  ...
# 0  TORNADO & HEAVY RAINFALL              False               True  ...
# 0                    FLOODS              False               True  ...
# 0                   TORNADO              False               True  ...
# 0                     FLOOD              False               True  ...
#
#             incidentEndDate      disasterCloseoutDate fipsStateCode  \
# 0  1953-05-02T04:00:00.000Z  1954-06-01T04:00:00.000Z            13
# 0  1953-05-15T04:00:00.000Z  1958-01-01T05:00:00.000Z            48
# 0  1953-06-06T04:00:00.000Z  1955-12-01T05:00:00.000Z            30
# 0  1953-06-11T04:00:00.000Z  1956-06-01T04:00:00.000Z            25
# 0  1953-06-11T04:00:00.000Z  1955-11-01T05:00:00.000Z            19
#
#   fipsCountyCode placeCode  designatedArea  declarationRequestNumber  \
# 0              0         0       Statewide                     53013
# 0              0         0       Statewide                     53003
# 0              0         0       Statewide                     53006
# 0              0         0       Statewide                     53009
# 0              0         0       Statewide                     53008
#
#                                hash               lastRefresh  \
# 0  2f28952448e0a666d367ca3f854c81ec  2020-10-05T14:21:20.694Z
# 0  c5a1a4a1030d6730d9c562cdbe7c830f  2020-10-05T14:21:20.696Z
# 0  59c5483387ca13c6a3c1bc692f4860e1  2020-10-05T14:21:20.698Z
# 0  6bab17e16984fc75f61a8445df3e95d9  2020-10-05T14:21:20.699Z
# 0  e258e9dd25fac73939f59c8ffb5308f5  2020-10-05T14:21:20.700Z
#
#                          id
# 0  5f7b2be031a8c6681cfb4342
# 0  5f7b2be031a8c6681cfb4345
# 0  5f7b2be031a8c6681cfb4348
# 0  5f7b2be031a8c6681cfb434b
# 0  5f7b2be031a8c6681cfb434e
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60356 entries, 0 to 0
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   femaDeclarationString     60356 non-null  object
#  1   disasterNumber            60356 non-null  int64
#  2   state                     60356 non-null  object
#  3   declarationType           60356 non-null  object
#  4   declarationDate           60356 non-null  object
#  5   fyDeclared                60356 non-null  int64
#  6   incidentType              60356 non-null  object
#  7   declarationTitle          60356 non-null  object
#  8   ihProgramDeclared         60356 non-null  bool
#  9   iaProgramDeclared         60356 non-null  bool
#  10  paProgramDeclared         60356 non-null  bool
#  11  hmProgramDeclared         60356 non-null  bool
#  12  incidentBeginDate         60356 non-null  object
#  13  incidentEndDate           52055 non-null  object
#  14  disasterCloseoutDate      43842 non-null  object
#  15  fipsStateCode             60356 non-null  int64
#  16  fipsCountyCode            60356 non-null  int64
#  17  placeCode                 60356 non-null  int64
#  18  designatedArea            60356 non-null  object
#  19  declarationRequestNumber  60356 non-null  int64
#  20  hash                      60356 non-null  object
#  21  lastRefresh               60356 non-null  object
#  22  id                        60356 non-null  object
# dtypes: bool(4), int64(6), object(13)
# memory usage: 9.4+ MB

# %%
# Select only the 5 states we're looking at for simplification purposes
reduced_df = df[(df['state'] == 'CA') | (df['state'] == 'LA') | (df['state'] == 'KS') | (df['state'] == 'TX') | (df['state'] == 'NY')]
reduced_df
# Out:
#    femaDeclarationString  disasterNumber state declarationType  \
# 0                DR-2-TX               2    TX              DR
# 0                DR-9-TX               9    TX              DR
# 0                DR-3-LA               3    LA              DR
# 0               DR-15-CA              15    CA              DR
# 0               DR-18-TX              18    TX              DR
# ..                   ...             ...   ...             ...
# 0             DR-4569-CA            4569    CA              DR
# 0             DR-4569-CA            4569    CA              DR
# 0             DR-4569-CA            4569    CA              DR
# 0             DR-4569-CA            4569    CA              DR
# 0             DR-4569-CA            4569    CA              DR
#
#              declarationDate  fyDeclared incidentType  \
# 0   1953-05-15T04:00:00.000Z        1953      Tornado
# 0   1953-06-19T04:00:00.000Z        1953        Flood
# 0   1953-05-29T04:00:00.000Z        1953        Flood
# 0   1954-02-05T05:00:00.000Z        1954        Flood
# 0   1954-07-01T04:00:00.000Z        1954        Flood
# ..                       ...         ...          ...
# 0   2020-10-17T00:49:00.000Z        2021         Fire
# 0   2020-10-17T00:49:00.000Z        2021         Fire
# 0   2020-10-17T00:49:00.000Z        2021         Fire
# 0   2020-10-17T00:49:00.000Z        2021         Fire
# 0   2020-10-17T00:49:00.000Z        2021         Fire
#
#             declarationTitle  ihProgramDeclared  iaProgramDeclared  ...  \
# 0   TORNADO & HEAVY RAINFALL              False               True  ...
# 0                      FLOOD              False               True  ...
# 0                      FLOOD              False               True  ...
# 0            FLOOD & EROSION              False               True  ...
# 0                      FLOOD              False               True  ...
# ..                       ...                ...                ...  ...
# 0                  WILDFIRES               True              False  ...
# 0                  WILDFIRES               True              False  ...
# 0                  WILDFIRES               True              False  ...
# 0                  WILDFIRES               True              False  ...
# 0                  WILDFIRES               True              False  ...
#
#              incidentEndDate      disasterCloseoutDate fipsStateCode  \
# 0   1953-05-15T04:00:00.000Z  1958-01-01T05:00:00.000Z            48
# 0   1953-06-19T04:00:00.000Z  1958-01-01T05:00:00.000Z            48
# 0   1953-05-29T04:00:00.000Z  1960-02-01T05:00:00.000Z            22
# 0   1954-02-05T05:00:00.000Z  1957-09-01T04:00:00.000Z             6
# 0   1954-07-01T04:00:00.000Z  1959-07-01T04:00:00.000Z            48
# ..                       ...                       ...           ...
# 0                        NaN                       NaN             6
# 0                        NaN                       NaN             6
# 0                        NaN                       NaN             6
# 0                        NaN                       NaN             6
# 0                        NaN                       NaN             6
#
#    fipsCountyCode placeCode      designatedArea  declarationRequestNumber  \
# 0               0         0           Statewide                     53003
# 0               0         0           Statewide                     53010
# 0               0         0           Statewide                     53005
# 0               0         0           Statewide                     54016
# 0               0         0           Statewide                     54004
# ..            ...       ...                 ...                       ...
# 0              97     99097     Sonoma (County)                     20302
# 0              45     99045  Mendocino (County)                     20302
# 0              19     99019     Fresno (County)                     20302
# 0              73     99073  San Diego (County)                     20302
# 0              89     99089     Shasta (County)                     20302
#
#                                 hash               lastRefresh  \
# 0   c5a1a4a1030d6730d9c562cdbe7c830f  2020-10-05T14:21:20.696Z
# 0   4485da27a9218458eb2d13a6c33a4c62  2020-10-05T14:21:20.700Z
# 0   745948932fd77a7c6dcd4de7059ff080  2020-10-05T14:21:20.697Z
# 0   328d7badea059a9bba05702e62a61c88  2020-10-05T14:21:20.702Z
# 0   c515d85a0d0f4c7fc56c154a9749ef0d  2020-10-05T14:21:20.703Z
# ..                               ...                       ...
# 0   7598219c340c696ad16ca19afef0d9a5  2020-10-28T13:21:46.792Z
# 0   7505a2bdb5723778bb1aeef2621c44c7  2020-10-28T13:21:46.790Z
# 0   8cbedeb64f5173864bf0894c81711fc9  2020-10-28T13:21:46.789Z
# 0   6886752be2748b90300245389487dffd  2020-10-28T13:21:46.791Z
# 0   24d3b97c7d72c746cdda0c15079d86e6  2020-10-28T13:21:46.792Z
#
#                           id
# 0   5f7b2be031a8c6681cfb4345
# 0   5f7b2be031a8c6681cfb4351
# 0   5f7b2be031a8c6681cfb4354
# 0   5f7b2be031a8c6681cfb4369
# 0   5f7b2be031a8c6681cfb436c
# ..                       ...
# 0   5f99706a0eb5d3623893a816
# 0   5f99706a0eb5d3623893a7fe
# 0   5f99706a0eb5d3623893a7f3
# 0   5f99706a0eb5d3623893a80b
# 0   5f99706a0eb5d3623893a830
#
# [11260 rows x 23 columns]

# %%
reduced_df.columns
# Out:
# Index(['femaDeclarationString', 'disasterNumber', 'state', 'declarationType',
#        'declarationDate', 'fyDeclared', 'incidentType', 'declarationTitle',
#        'ihProgramDeclared', 'iaProgramDeclared', 'paProgramDeclared',
#        'hmProgramDeclared', 'incidentBeginDate', 'incidentEndDate',
#        'disasterCloseoutDate', 'fipsStateCode', 'fipsCountyCode', 'placeCode',
#        'designatedArea', 'declarationRequestNumber', 'hash', 'lastRefresh',
#        'id'],
#       dtype='object')

# %%
# drop unnecessary columns
reduced_df.drop(columns = ['femaDeclarationString', 'declarationDate', 'ihProgramDeclared', 'iaProgramDeclared', 'paProgramDeclared', 
                           'hmProgramDeclared', 'placeCode', 'fipsStateCode', 'fipsCountyCode', 'declarationRequestNumber', 'hash', 'lastRefresh', 'id'], inplace = True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### Historical Data Analysis

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11260 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   disasterNumber        11260 non-null  int64
#  1   state                 11260 non-null  object
#  2   declarationType       11260 non-null  object
#  3   fyDeclared            11260 non-null  int64
#  4   incidentType          11260 non-null  object
#  5   declarationTitle      11260 non-null  object
#  6   incidentBeginDate     11260 non-null  object
#  7   incidentEndDate       9867 non-null   object
#  8   disasterCloseoutDate  8024 non-null   object
#  9   designatedArea        11260 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 967.7+ KB

# %%
# reset index (they're all 0s)
reduced_df.reset_index(drop=True, inplace = True)

# %%
# export to CSV
reduced_df.to_csv('DisasterSummariesREDUCED.csv')

# %%
reduced_df.head(3)
# Out:
#    disasterNumber state declarationType  fyDeclared incidentType  \
# 0               2    TX              DR        1953      Tornado
# 1               9    TX              DR        1953        Flood
# 2               3    LA              DR        1953        Flood
#
#            declarationTitle         incidentBeginDate  \
# 0  TORNADO & HEAVY RAINFALL  1953-05-15T04:00:00.000Z
# 1                     FLOOD  1953-06-19T04:00:00.000Z
# 2                     FLOOD  1953-05-29T04:00:00.000Z
#
#             incidentEndDate      disasterCloseoutDate designatedArea
# 0  1953-05-15T04:00:00.000Z  1958-01-01T05:00:00.000Z      Statewide
# 1  1953-06-19T04:00:00.000Z  1958-01-01T05:00:00.000Z      Statewide
# 2  1953-05-29T04:00:00.000Z  1960-02-01T05:00:00.000Z      Statewide

# %%
# Filter by disaster type

# %%
# A look at most common incident types
reduced_df[['incidentType']].value_counts().head(40)
# Out:
# incidentType
# Hurricane           2820
# Severe Storm(s)     2591
# Fire                1736
# Flood               1580
# Biological          1137
# Snow                 341
# Other                226
# Coastal Storm        225
# Drought              210
# Tornado              136
# Severe Ice Storm     132
# Freezing              73
# Earthquake            37
# Dam/Levee Break        5
# Fishing Losses         4
# Toxic Substances       3
# Tsunami                3
# Human Cause            1
# dtype: int64

# %%
# Most common incident types by state
reduced_df[['state','incidentType']].value_counts().head(40)
# Out:
# state  incidentType
# TX     Hurricane           1298
#        Fire                1216
# LA     Hurricane           1143
# KS     Severe Storm(s)      975
# TX     Severe Storm(s)      760
#        Biological           515
#        Flood                503
# CA     Fire                 428
# NY     Severe Storm(s)      368
# LA     Flood                356
# CA     Severe Storm(s)      325
#        Flood                320
# NY     Snow                 249
# KS     Biological           233
# NY     Hurricane            216
#        Flood                215
# KS     Flood                186
# LA     Severe Storm(s)      163
# TX     Drought              149
# LA     Biological           144
#        Coastal Storm        140
# NY     Biological           129
#        Other                126
# CA     Biological           116
# KS     Hurricane            105
# NY     Fire                  64
# KS     Tornado               59
# CA     Hurricane             58
#        Freezing              57
# TX     Other                 56
# KS     Severe Ice Storm      55
#        Snow                  50
# TX     Tornado               50
# CA     Drought               47
# TX     Severe Ice Storm      46
# CA     Coastal Storm         43
# TX     Coastal Storm         42
# LA     Snow                  42
#        Other                 41
# CA     Earthquake            31
# dtype: int64

# %%
# States with disaster history:

# %%
reduced_df[['state', 'disasterNumber']].groupby('state').count().sort_values('disasterNumber', ascending=False)
# Out:
#        disasterNumber
# state
# TX               4651
# LA               2073
# KS               1682
# CA               1438
# NY               1416

# %%
# A look at disasterNumber ID counts by state
reduced_df[['state', 'disasterNumber']].value_counts()
# Out:
# state  disasterNumber
# TX     1239              257
#        4485              257
#        3458              257
#        3261              255
#        3216              254
#                         ...
#        2133                1
#        2132                1
#        2131                1
#        2130                1
# CA     15                  1
# Length: 978, dtype: int64

# %%
reduced_df['state'].unique()
# Out:
# array(['TX', 'LA', 'CA', 'NY', 'KS'], dtype=object)

# %% [markdown]
# The count of state values don't seem to reflect the actual number of unique disaster cases by state. So let's break it down by looping through each unique disaster case.

# %%
count_TX = 0
count_LA = 0
count_KS = 0
count_CA = 0
count_NY = 0

for i in range(len(list(reduced_df[['state', 'disasterNumber']].value_counts().items()))):
    if list(reduced_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'TX':
        count_TX += 1
    elif list(reduced_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'LA':
        count_LA += 1
    elif list(reduced_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'KS':
        count_KS += 1    
    elif list(reduced_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'CA':
        count_CA += 1
    elif list(reduced_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'NY':
        count_NY += 1

print(f'Count of TX: {count_TX}')
print(f'Count of LA: {count_LA}')
print(f'Count of KS: {count_KS}')
print(f'Count of CA: {count_CA}')
print(f'Count of NY: {count_NY}')
print(count_TX + count_LA + count_KS + count_CA + count_NY)
# Out:
# Count of TX: 360
# Count of LA: 94
# Count of KS: 79
# Count of CA: 343
# Count of NY: 102
# 978

# %%
reduced_df[reduced_df['state'] == 'TX']['incidentType'].value_counts()
# Out:
# Hurricane           1298
# Fire                1216
# Severe Storm(s)      760
# Biological           515
# Flood                503
# Drought              149
# Other                 56
# Tornado               50
# Severe Ice Storm      46
# Coastal Storm         42
# Freezing              16
# Name: incidentType, dtype: int64

# %%
reduced_df[reduced_df['state'] == 'CA']['incidentType'].value_counts()
# Out:
# Fire               428
# Severe Storm(s)    325
# Flood              320
# Biological         116
# Hurricane           58
# Freezing            57
# Drought             47
# Coastal Storm       43
# Earthquake          31
# Dam/Levee Break      5
# Fishing Losses       4
# Tsunami              3
# Other                1
# Name: incidentType, dtype: int64

# %%
reduced_df[reduced_df['state'] == 'NY']['incidentType'].value_counts()
# Out:
# Severe Storm(s)     368
# Snow                249
# Hurricane           216
# Flood               215
# Biological          129
# Other               126
# Fire                 64
# Severe Ice Storm     23
# Drought              14
# Earthquake            6
# Tornado               3
# Toxic Substances      2
# Human Cause           1
# Name: incidentType, dtype: int64

# %%
reduced_df[reduced_df['state'] == 'LA']['incidentType'].value_counts()
# Out:
# Hurricane           1143
# Flood                356
# Severe Storm(s)      163
# Biological           144
# Coastal Storm        140
# Snow                  42
# Other                 41
# Tornado               24
# Fire                  11
# Severe Ice Storm       8
# Toxic Substances       1
# Name: incidentType, dtype: int64

# %%
reduced_df[reduced_df['state'] == 'KS']['incidentType'].value_counts()
# Out:
# Severe Storm(s)     975
# Biological          233
# Flood               186
# Hurricane           105
# Tornado              59
# Severe Ice Storm     55
# Snow                 50
# Fire                 17
# Other                 2
# Name: incidentType, dtype: int64

# %% [markdown]
# Texas and California have by far the most number of cases in historical records, with most of them being hurricanes and fires. New York has a lot of storms and snow events, while Louisiana has many hurricanes and Kansas has lots of storms.

# %%
# The disaster declarationType two-letter codes are the following:
# DR = major disaster declaration
# EM = emergency declaration
# FM = fire management assistance declaratiom
# FS = fire suppression authorization

# %% [markdown]
# Two character code that defines if the disaster is a Major Disaster Declaration (DR), Emergency Declaration (EM), Fire Management Assistance Declaration (FM), or Fire Suppression Authorization (FS).

# %%
# A look at Texas

# %%
tx = reduced_df[reduced_df['state'] == 'TX']
tx
# Out:
#        disasterNumber state declarationType  fyDeclared incidentType  \
# 0                   2    TX              DR        1953      Tornado
# 1                   9    TX              DR        1953        Flood
# 4                  18    TX              DR        1954        Flood
# 12                 72    TX              DR        1957    Hurricane
# 14                 85    TX              DR        1958      Tornado
# ...               ...   ...             ...         ...          ...
# 11058            5264    TX              FM        2018         Fire
# 11064            5288    TX              FM        2019         Fire
# 11179            3540    TX              EM        2020    Hurricane
# 11180            3540    TX              EM        2020    Hurricane
# 11181            3540    TX              EM        2020    Hurricane
#
#                            declarationTitle         incidentBeginDate  \
# 0                  TORNADO & HEAVY RAINFALL  1953-05-15T04:00:00.000Z
# 1                                     FLOOD  1953-06-19T04:00:00.000Z
# 4                                     FLOOD  1954-07-01T04:00:00.000Z
# 12     HURRICANE, RAIN, WIND, HAIL & FLOODS  1957-04-29T04:00:00.000Z
# 14           TORNADOES, RAIN, HAIL & FLOODS  1958-06-06T04:00:00.000Z
# ...                                     ...                       ...
# 11058                        PARK ROAD FIRE  2018-07-29T17:05:43.000Z
# 11064                    COPPER BREAKS FIRE  2019-08-16T21:00:00.000Z
# 11179       TROPICAL STORMS MARCO AND LAURA  2020-08-23T12:00:00.000Z
# 11180       TROPICAL STORMS MARCO AND LAURA  2020-08-23T12:00:00.000Z
# 11181       TROPICAL STORMS MARCO AND LAURA  2020-08-23T12:00:00.000Z
#
#                 incidentEndDate      disasterCloseoutDate     designatedArea
# 0      1953-05-15T04:00:00.000Z  1958-01-01T05:00:00.000Z          Statewide
# 1      1953-06-19T04:00:00.000Z  1958-01-01T05:00:00.000Z          Statewide
# 4      1954-07-01T04:00:00.000Z  1959-07-01T04:00:00.000Z          Statewide
# 12     1957-04-29T04:00:00.000Z  1961-03-01T05:00:00.000Z          Statewide
# 14     1958-06-06T04:00:00.000Z  1961-03-01T05:00:00.000Z          Statewide
# ...                         ...                       ...                ...
# 11058                       NaN                       NaN    Burnet (County)
# 11064                       NaN                       NaN  Hardeman (County)
# 11179  2020-08-28T03:00:00.000Z                       NaN     Ellis (County)
# 11180  2020-08-28T03:00:00.000Z                       NaN      Camp (County)
# 11181  2020-08-28T03:00:00.000Z                       NaN   Tarrant (County)
#
# [4651 rows x 10 columns]

# %%
# top 30 most frequent years in the records
tx['fyDeclared'].value_counts().head(30)
# Out:
# 2005    763
# 2020    616
# 2008    476
# 1999    297
# 1998    293
# 2006    277
# 2011    261
# 2016    168
# 1993    153
# 2007    116
# 2015    113
# 1989    108
# 1996    104
# 1992     97
# 2003     90
# 2001     80
# 1990     74
# 2017     53
# 2002     52
# 2010     46
# 2019     40
# 1995     39
# 1967     29
# 1966     27
# 1979     26
# 1973     22
# 1997     21
# 2000     20
# 1970     18
# 2009     16
# Name: fyDeclared, dtype: int64

# %%
# A look at NY

# %%
# A look at KS

# %%
# A look at CA

# %%
# A look at LA

# %% [markdown]
# ### Ongoing Disasters

# %%
# take a look at null values in Incident End Date columns
reduced_df[reduced_df['incidentEndDate'].isna()]['incidentBeginDate'].value_counts().head(30)
# Out:
# 2020-01-20T19:00:00.000Z    1079
# 2020-10-06T12:00:00.000Z      64
# 2020-10-26T12:00:00.000Z      64
# 2020-01-20T05:01:00.000Z      58
# 2020-09-04T14:00:00.000Z      10
# 2020-08-17T04:00:00.000Z       9
# 2011-02-27T05:00:00.000Z       4
# 2020-08-01T04:00:00.000Z       3
# 2020-10-26T22:49:00.000Z       3
# 2006-01-05T05:00:00.000Z       3
# 2008-06-22T00:00:00.000Z       2
# 2020-08-18T04:00:00.000Z       2
# 2017-10-09T03:16:00.000Z       2
# 2017-10-09T09:35:00.000Z       2
# 2005-12-27T05:00:00.000Z       2
# 2020-09-27T14:59:00.000Z       2
# 2017-10-09T03:34:00.000Z       2
# 2019-10-11T01:01:00.000Z       2
# 2006-08-18T04:00:00.000Z       2
# 2006-01-01T05:00:00.000Z       2
# 2020-08-21T02:40:00.000Z       2
# 2018-11-08T19:25:00.000Z       2
# 2020-09-06T04:00:00.000Z       2
# 2020-08-20T14:00:00.000Z       2
# 2017-12-04T23:00:00.000Z       2
# 2007-10-21T01:35:00.000Z       2
# 2017-10-09T19:19:00.000Z       2
# 2019-10-30T17:50:00.000Z       1
# 2008-11-15T02:54:00.000Z       1
# 2006-01-08T05:00:00.000Z       1
# Name: incidentBeginDate, dtype: int64

# %% [markdown]
# Null values in this column implies that the disaster or incident is still ongoing. Most null values are from recent dates, as expected. However, there are some values from over 10 years ago that seem to be errors or unusual cases.

# %%
# create a dataframe with only active disasters (those in which incident end date is missing)
active_df = reduced_df[reduced_df['incidentEndDate'].isna()]
active_df
# Out:
#        disasterNumber state declarationType incidentType  \
# 5171             2506    CA              FM         Fire
# 5207             2591    TX              FM         Fire
# 5208             2596    TX              FM         Fire
# 5209             2593    TX              FM         Fire
# 5210             2598    TX              FM         Fire
# ...               ...   ...             ...          ...
# 11255            4569    CA              DR         Fire
# 11256            4569    CA              DR         Fire
# 11257            4569    CA              DR         Fire
# 11258            4569    CA              DR         Fire
# 11259            4569    CA              DR         Fire
#
#            declarationTitle         incidentBeginDate incidentEndDate  \
# 5171          PARADISE FIRE  2003-10-26T05:34:00.000Z             NaN
# 5207   CALLAHAN COUNTY FIRE  2005-12-27T05:00:00.000Z             NaN
# 5208            CARBON FIRE  2006-01-01T05:00:00.000Z             NaN
# 5209         KENNEDALE FIRE  2005-12-27T05:00:00.000Z             NaN
# 5210          RINGGOLD FIRE  2006-01-01T05:00:00.000Z             NaN
# ...                     ...                       ...             ...
# 11255             WILDFIRES  2020-09-04T14:00:00.000Z             NaN
# 11256             WILDFIRES  2020-09-04T14:00:00.000Z             NaN
# 11257             WILDFIRES  2020-09-04T14:00:00.000Z             NaN
# 11258             WILDFIRES  2020-09-04T14:00:00.000Z             NaN
# 11259             WILDFIRES  2020-09-04T14:00:00.000Z             NaN
#
#            disasterCloseoutDate      designatedArea
# 5171   2004-01-21T05:00:00.000Z  San Diego (County)
# 5207   2008-06-26T04:00:00.000Z   Callahan (County)
# 5208   2008-06-26T04:00:00.000Z   Eastland (County)
# 5209   2008-06-26T04:00:00.000Z    Tarrant (County)
# 5210   2008-06-26T04:00:00.000Z   Montague (County)
# ...                         ...                 ...
# 11255                       NaN     Sonoma (County)
# 11256                       NaN  Mendocino (County)
# 11257                       NaN     Fresno (County)
# 11258                       NaN  San Diego (County)
# 11259                       NaN     Shasta (County)
#
# [1393 rows x 9 columns]

# %%
# a look at counts of disasters by incident type
active_df[['incidentType']].value_counts()
# Out:
# incidentType
# Biological      1137
# Hurricane        128
# Fire             128
# dtype: int64

# %%
# a look at most frequent disaster titles with counts
active_df[['declarationTitle']].value_counts().head(30)
# Out:
# declarationTitle
# COVID-19 PANDEMIC             571
# COVID-19                      566
# HURRICANE DELTA                64
# TROPICAL STORM ZETA            64
# WILDFIRES                      10
# LNU LIGHTNING FIRE COMPLEX      5
# BLUE RIDGE FIRE                 3
# APPLE FIRE                      3
# BEAR FIRE                       3
# PARTRICK FIRE                   2
# SADDLERIDGE FIRE                2
# RANCH FIRE                      2
# CAMP FIRE                       2
# SCU LIGTNING COMPLEX FIRE       2
# HILL FIRE                       2
# CADDO II FIRE COMPLEX           2
# WOOLSEY FIRE                    2
# GLASS FIRE                      2
# THOMAS FIRE                     2
# CREEK FIRE                      2
# TUBBS FIRE                      2
# CZU LIGHTNING FIRE COMPLEX      2
# ATLAS FIRE                      2
# WILD FIRE                       2
# CASCADE FIRE                    2
# GAP FIRE                        1
# GETTY FIRE                      1
# ZOGG FIRE                       1
# GRASS VALLEY FIRE               1
# HARRIS FIRE                     1
# dtype: int64

# %%
# Check to see individual entry 
list(active_df[['state', 'incidentType', 'declarationTitle']].groupby('state'))[0][1]
# Out:
#       state incidentType declarationTitle
# 5171     CA         Fire    PARADISE FIRE
# 5248     CA         Fire    BUCKWEED FIRE
# 5249     CA         Fire       WITCH FIRE
# 5250     CA         Fire      HARRIS FIRE
# 5251     CA         Fire       RANCH FIRE
# ...     ...          ...              ...
# 11255    CA         Fire        WILDFIRES
# 11256    CA         Fire        WILDFIRES
# 11257    CA         Fire        WILDFIRES
# 11258    CA         Fire        WILDFIRES
# 11259    CA         Fire        WILDFIRES
#
# [208 rows x 3 columns]

# %%
list(active_df[['state', 'incidentType', 'declarationTitle']].groupby('state'))[4]
# Out:
# ('TX',
#        state incidentType      declarationTitle
#  5207     TX         Fire  CALLAHAN COUNTY FIRE
#  5208     TX         Fire           CARBON FIRE
#  5209     TX         Fire        KENNEDALE FIRE
#  5210     TX         Fire         RINGGOLD FIRE
#  5211     TX         Fire      CEDAR CREEK FIRE
#  ...     ...          ...                   ...
#  10740    TX   Biological     COVID-19 PANDEMIC
#  10956    TX         Fire   DOUBLE DIAMOND FIRE
#  11053    TX         Fire              259 FIRE
#  11058    TX         Fire        PARK ROAD FIRE
#  11064    TX         Fire    COPPER BREAKS FIRE
#
#  [550 rows x 3 columns])

# %%
active_df['state'].value_counts()
# Out:
# TX    550
# LA    272
# KS    234
# CA    208
# NY    129
# Name: state, dtype: int64

# %% [markdown]
# The count of state values don't seem to reflect the actual number of unique disaster cases by state. So let's break it down by looping through each unique disaster case.

# %%
count_TX = 0
count_LA = 0
count_KS = 0
count_CA = 0
count_NY = 0

list_TX = []
list_LA = []
list_KS = []
list_CA = []
list_NY = []

for i in range(len(list(active_df[['state', 'disasterNumber']].value_counts().items()))):
    if list(active_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'TX':
        count_TX += 1
        list_TX.append()
    elif list(active_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'LA':
        count_LA += 1
    elif list(active_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'KS':
        count_KS += 1    
    elif list(active_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'CA':
        count_CA += 1
    elif list(active_df[['state', 'disasterNumber']].value_counts().items())[i][0][0] == 'NY':
        count_NY += 1

print(f'Count of TX: {count_TX}')
print(f'Count of LA: {count_LA}')
print(f'Count of KS: {count_KS}')
print(f'Count of CA: {count_CA}')
print(f'Count of NY: {count_NY}')
print(count_TX + count_LA + count_KS + count_CA + count_NY)
# Out:
# Count of TX: 37
# Count of LA: 5
# Count of KS: 6
# Count of CA: 62
# Count of NY: 3
# 113

# %% [markdown]
# ### COVID Data

# %%
ca = pd.read_csv('ca_positivity.csv')

# %%
ca.tail()
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 234  2020-10-24    CA              5945                    125886
# 235  2020-10-25    CA              5219                    178706
# 236  2020-10-26    CA              2981                    194944
# 237  2020-10-27    CA              3188                    144220
# 238  2020-10-28    CA              4515                     96547
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 234      28355.0     852468.0                        3.33
# 235      30712.0     895823.0                        3.43
# 236      30219.0     940421.0                        3.21
# 237      30121.0     937979.0                        3.21
# 238      30929.0     930457.0                        3.32
#
#      Positivity Rate (1-day)
# 234                     4.72
# 235                     2.92
# 236                     1.53
# 237                     2.21
# 238                     4.68

# %%
la = pd.read_csv('la_positivity.csv')

# %%
la.tail()
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 231  2020-10-24    LA                 0                         0
# 232  2020-10-25    LA               972                     26269
# 233  2020-10-26    LA               227                      5059
# 234  2020-10-27    LA               922                     20711
# 235  2020-10-28    LA              1098                     15124
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 231       4877.0     105586.0                        4.62
# 232       4706.0     104909.0                        4.49
# 233       4732.0     105102.0                        4.50
# 234       4955.0     106820.0                        4.64
# 235       4690.0     106997.0                        4.38
#
#      Positivity Rate (1-day)
# 231                      NaN
# 232                     3.70
# 233                     4.49
# 234                     4.45
# 235                     7.26

# %%
ks = pd.read_csv('ks_positivity.csv')
ks.tail()
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 232  2020-10-24    KS                 0                         0
# 233  2020-10-25    KS                 0                         0
# 234  2020-10-26    KS              2446                      9669
# 235  2020-10-27    KS                 0                         0
# 236  2020-10-28    KS              3369                      7102
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 232       5375.0      27073.0                       19.85
# 233       5375.0      27073.0                       19.85
# 234       5708.0      27537.0                       20.73
# 235       5708.0      27537.0                       20.73
# 236       7589.0      27524.0                       27.57
#
#      Positivity Rate (1-day)
# 232                      NaN
# 233                      NaN
# 234                    25.30
# 235                      NaN
# 236                    47.44

# %%
tx = pd.read_csv('tx_positivity.csv')
tx.tail()
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 234  2020-10-24    TX              6499                     98609
# 235  2020-10-25    TX              4304                     52047
# 236  2020-10-26    TX              4700                     46908
# 237  2020-10-27    TX              7292                     74290
# 238  2020-10-28    TX              5627                     50037
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 234      37508.0     435959.0                        8.60
# 235      38596.0     435323.0                        8.87
# 236      41402.0     425107.0                        9.74
# 237      40810.0     439114.0                        9.29
# 238      41185.0     458603.0                        8.98
#
#      Positivity Rate (1-day)
# 234                     6.59
# 235                     8.27
# 236                    10.02
# 237                     9.82
# 238                    11.25

# %%
ny = pd.read_csv('ny_positivity.csv')
ny.tail()
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 234  2020-10-24    NY              2061                    156940
# 235  2020-10-25    NY              1632                    120830
# 236  2020-10-26    NY              1191                     82117
# 237  2020-10-27    NY              1991                    111618
# 238  2020-10-28    NY              2031                    129660
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 234      10941.0     859890.0                        1.27
# 235      11183.0     851957.0                        1.31
# 236      11376.0     852065.0                        1.34
# 237      12166.0     873143.0                        1.39
# 238      12171.0     878014.0                        1.39
#
#      Positivity Rate (1-day)
# 234                     1.31
# 235                     1.35
# 236                     1.45
# 237                     1.78
# 238                     1.57

# %%
combined_covid = ca.append(la)

# %%
combined_covid = combined_covid.append(ks)

# %%
combined_covid = combined_covid.append(tx)

# %%
combined_covid = combined_covid.append(ny)

# %%
combined_covid.reset_index(drop=True)
# Out:
#             date state  positiveIncrease  totalTestResultsIncrease  \
# 0     2020-03-04    CA                 0                         0
# 1     2020-03-05    CA                 0                         0
# 2     2020-03-06    CA                 7                         7
# 3     2020-03-07    CA                 9                         9
# 4     2020-03-08    CA                19                        19
# ...          ...   ...               ...                       ...
# 1185  2020-10-24    NY              2061                    156940
# 1186  2020-10-25    NY              1632                    120830
# 1187  2020-10-26    NY              1191                     82117
# 1188  2020-10-27    NY              1991                    111618
# 1189  2020-10-28    NY              2031                    129660
#
#       pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 0             NaN          NaN                         NaN
# 1             NaN          NaN                         NaN
# 2             NaN          NaN                         NaN
# 3             NaN          NaN                         NaN
# 4             NaN          NaN                         NaN
# ...           ...          ...                         ...
# 1185      10941.0     859890.0                        1.27
# 1186      11183.0     851957.0                        1.31
# 1187      11376.0     852065.0                        1.34
# 1188      12166.0     873143.0                        1.39
# 1189      12171.0     878014.0                        1.39
#
#       Positivity Rate (1-day)
# 0                         NaN
# 1                         NaN
# 2                      100.00
# 3                      100.00
# 4                      100.00
# ...                       ...
# 1185                     1.31
# 1186                     1.35
# 1187                     1.45
# 1188                     1.78
# 1189                     1.57
#
# [1190 rows x 8 columns]

# %%
combined_covid.sort_values('date').tail(10)
# Out:
#            date state  positiveIncrease  totalTestResultsIncrease  \
# 237  2020-10-27    TX              7292                     74290
# 234  2020-10-27    LA               922                     20711
# 237  2020-10-27    CA              3188                    144220
# 235  2020-10-27    KS                 0                         0
# 237  2020-10-27    NY              1991                    111618
# 235  2020-10-28    LA              1098                     15124
# 238  2020-10-28    TX              5627                     50037
# 236  2020-10-28    KS              3369                      7102
# 238  2020-10-28    CA              4515                     96547
# 238  2020-10-28    NY              2031                    129660
#
#      pos_inc_sum  tot_inc_sum  Positivity Rate (7-day MA)  \
# 237      40810.0     439114.0                        9.29
# 234       4955.0     106820.0                        4.64
# 237      30121.0     937979.0                        3.21
# 235       5708.0      27537.0                       20.73
# 237      12166.0     873143.0                        1.39
# 235       4690.0     106997.0                        4.38
# 238      41185.0     458603.0                        8.98
# 236       7589.0      27524.0                       27.57
# 238      30929.0     930457.0                        3.32
# 238      12171.0     878014.0                        1.39
#
#      Positivity Rate (1-day)
# 237                     9.82
# 234                     4.45
# 237                     2.21
# 235                      NaN
# 237                     1.78
# 235                     7.26
# 238                    11.25
# 236                    47.44
# 238                     4.68
# 238                     1.57

# %%
# combined_covid.groupby('state')

# %%
combined_covid.to_csv('combined_covid.csv')
